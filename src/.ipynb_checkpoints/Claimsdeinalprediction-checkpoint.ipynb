# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
patients_df = pd.read_csv("C:/Users/kandu/Documents/Data Analysis Projects/Claims Denial Prediction/data/raw_new/patients.csv")
claims_df = pd.read_csv("C:/Users/kandu/Documents/Data Analysis Projects/Claims Denial Prediction/data/raw_new/claims.csv")
payers_df = pd.read_csv("C:/Users/kandu/Documents/Data Analysis Projects/Claims Denial Prediction/data/raw_new/payers.csv")
providers_df = pd.read_csv("C:/Users/kandu/Documents/Data Analysis Projects/Claims Denial Prediction/data/raw_new/providers.csv")
revenue_df = pd.read_csv("C:/Users/kandu/Documents/Data Analysis Projects/Claims Denial Prediction/data/raw_new/revenue.csv")
externalfact_df = pd.read_csv("C:/Users/kandu/Documents/Data Analysis Projects/Claims Denial Prediction/data/raw_new/external_factors.csv")

# %%
print(patients_df.info())
print(claims_df.info())
print(payers_df.info())
print(providers_df.info())
print(revenue_df.info())
print(externalfact_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PatientID      10000 non-null  object
#  1   Age            10000 non-null  int64
#  2   Gender         10000 non-null  object
#  3   City           10000 non-null  object
#  4   State          10000 non-null  object
#  5   InsuranceType  10000 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 468.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ClaimID         50000 non-null  object
#  1   PatientID       50000 non-null  object
#  2   PayerID         50000 non-null  object
#  3   ProviderID      50000 non-null  object
#  4   ClaimAmount     50000 non-null  float64
#  5   Reimbursement   50000 non-null  float64
#  6   DenialStatus    50000 non-null  object
#  7   ServiceDate     50000 non-null  object
#  8   SubmissionDate  50000 non-null  object
#  9   ProcessedDate   50000 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 3.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PayerID            50 non-null     object
#  1   PayerName          50 non-null     object
#  2   PayerCategory      50 non-null     object
#  3   ReimbursementRate  50 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProviderID    500 non-null    object
#  1   ProviderName  500 non-null    object
#  2   Specialty     500 non-null    object
#  3   City          500 non-null    object
#  4   State         500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MonthID          36 non-null     object
#  1   TotalRevenue     36 non-null     float64
#  2   ClaimsProcessed  36 non-null     int64
#  3   PatientsServed   36 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MonthID        36 non-null     object
#  1   InflationRate  36 non-null     float64
#  2   PublicEvents   11 non-null     object
#  3   PolicyChanges  5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 1.3+ KB
# None

# %%
print(patients_df.describe())
print(claims_df.describe())
print(payers_df.describe())
print(revenue_df.describe())
print(externalfact_df.describe())
# Out:
#                 Age
# count  10000.000000
# mean      53.418300
# std       20.795893
# min       18.000000
# 25%       35.000000
# 50%       53.000000
# 75%       71.000000
# max       89.000000
#         ClaimAmount  Reimbursement
# count  50000.000000   50000.000000
# mean    5070.530641    3421.662119
# std     2859.353539    2462.731736
# min      100.020000       0.000000
# 25%     2594.402500    1262.337500
# 50%     5074.420000    3279.315000
# 75%     7549.197500    5255.067500
# max     9999.840000    9954.850000
#        ReimbursementRate
# count          50.000000
# mean            0.749800
# std             0.148825
# min             0.510000
# 25%             0.632500
# 50%             0.720000
# 75%             0.870000
# max             1.000000
#        TotalRevenue  ClaimsProcessed  PatientsServed
# count  3.600000e+01        36.000000       36.000000
# mean   4.752308e+06      1388.888889     1295.000000
# std    7.326048e+05       211.776672      192.791671
# min    7.774786e+05       240.000000      239.000000
# 25%    4.761476e+06      1392.750000     1304.750000
# 50%    4.852037e+06      1425.000000     1333.000000
# 75%    5.001112e+06      1467.500000     1361.250000
# max    5.321474e+06      1556.000000     1444.000000
#        InflationRate
# count      36.000000
# mean        0.030000
# std         0.012275
# min         0.010000
# 25%         0.019750
# 50%         0.031000
# 75%         0.040250
# max         0.048000

# %%
print(patients_df.head())
print(claims_df.head())
print(payers_df.head())
print(providers_df.head())
print(revenue_df.head())
print(externalfact_df.head())
# Out:
#   PatientID  Age  Gender          City State InsuranceType
# 0    P00001   72    Male    Chavezfurt    SC    Government
# 1    P00002   53  Female   Hollandview    MN       Private
# 2    P00003   54  Female  Port Lindsey    NM    Government
# 3    P00004   31  Female   Travismouth    IN       Private
# 4    P00005   44    Male  Barrychester    KS    Government
#    ClaimID PatientID PayerID ProviderID  ClaimAmount  Reimbursement  \
# 0  C000001    P02949   PY039     PR0388      6188.33        5860.73
# 1  C000002    P03936   PY038     PR0253      4516.85        2678.98
# 2  C000003    P06831   PY033     PR0244      7085.31           0.00
# 3  C000004    P03710   PY042     PR0038      5853.90        3390.23
# 4  C000005    P01290   PY023     PR0014      3015.11           0.00
#
#   DenialStatus ServiceDate SubmissionDate ProcessedDate
# 0           No    9/3/2022      10/1/2022     10/8/2022
# 1           No   12/6/2022     12/15/2022    12/22/2022
# 2          Yes   11/5/2023      11/8/2023    11/22/2023
# 3           No   10/9/2022     10/11/2022     11/7/2022
# 4          Yes  10/25/2022     11/16/2022     12/3/2022
#   PayerID                  PayerName PayerCategory  ReimbursementRate
# 0   PY001      Boyd, Garcia and Ward       Private               0.64
# 1   PY002  Rojas, Richards and Brown       Private               0.58
# 2   PY003              Salazar Group    Government               0.59
# 3   PY004             Williams Group       Private               0.52
# 4   PY005                  Curry LLC       Private               0.93
#   ProviderID       ProviderName         Specialty             City State
# 0     PR0001         Grant Wood        Pediatrics     Brittanyland    LA
# 1     PR0002   Christian Morton       Orthopedics  Port Scotthaven    KY
# 2     PR0003  Michele Rodriguez  General Medicine       Zacharyton    SC
# 3     PR0004      Tammy Kennedy  General Medicine     Bryanchester    OH
# 4     PR0005       Kelly Jordan         Neurology         New John    AZ
#    MonthID  TotalRevenue  ClaimsProcessed  PatientsServed
# 0  2022-01     777478.64              240             239
# 1  2022-02    3840660.15             1097            1045
# 2  2022-03    4812872.62             1471            1361
# 3  2022-04    5000918.17             1485            1371
# 4  2022-05    5278201.83             1556            1444
#    MonthID  InflationRate      PublicEvents     PolicyChanges
# 0  2022-01          0.032  Natural Disaster               NaN
# 1  2022-02          0.025  Natural Disaster               NaN
# 2  2022-03          0.033          Pandemic               NaN
# 3  2022-04          0.048               NaN  Insurance Reform
# 4  2022-05          0.019               NaN               NaN

# %%
#Convert to datetime
claims_df['ServiceDate'] = pd.to_datetime(claims_df['ServiceDate'])
claims_df['SubmissionDate'] = pd.to_datetime(claims_df['SubmissionDate'])
claims_df['ProcessedDate'] = pd.to_datetime(claims_df['ProcessedDate'])

# %%
# Convert to datetime
revenue_df['MonthID'] = pd.to_datetime(revenue_df['MonthID'], format='%Y-%m')
externalfact_df['MonthID'] = pd.to_datetime(externalfact_df['MonthID'], format='%Y-%m')

# Convert to Period (Year-Month)
revenue_df['MonthID'] = revenue_df['MonthID'].dt.to_period('M')
externalfact_df['MonthID'] = externalfact_df['MonthID'].dt.to_period('M')

# %%
print(revenue_df.head())
# Out:
#    MonthID  TotalRevenue  ClaimsProcessed  PatientsServed
# 0  2022-01     777478.64              240             239
# 1  2022-02    3840660.15             1097            1045
# 2  2022-03    4812872.62             1471            1361
# 3  2022-04    5000918.17             1485            1371
# 4  2022-05    5278201.83             1556            1444

# %%
#Handling missing values
print(patients_df.isnull().sum())
print(claims_df.isnull().sum())
print(payers_df.isnull().sum())
print(providers_df.isnull().sum())
print(revenue_df.isnull().sum())
print(externalfact_df.isnull().sum())
# Out:
# PatientID        0
# Age              0
# Gender           0
# City             0
# State            0
# InsuranceType    0
# dtype: int64
# ClaimID           0
# PatientID         0
# PayerID           0
# ProviderID        0
# ClaimAmount       0
# Reimbursement     0
# DenialStatus      0
# ServiceDate       0
# SubmissionDate    0
# ProcessedDate     0
# dtype: int64
# PayerID              0
# PayerName            0
# PayerCategory        0
# ReimbursementRate    0
# dtype: int64
# ProviderID      0
# ProviderName    0
# Specialty       0
# City            0
# State           0
# dtype: int64
# MonthID            0
# TotalRevenue       0
# ClaimsProcessed    0
# PatientsServed     0
# dtype: int64
# MonthID           0
# InflationRate     0
# PublicEvents     25
# PolicyChanges    31
# dtype: int64

# %%
#Filling null values 
externalfact_df['PublicEvents'] = externalfact_df['PublicEvents'].fillna("No Events")
externalfact_df['PolicyChanges'] = externalfact_df['PolicyChanges'].fillna("No Changes")

# %%
#Duplicate values
print(patients_df.duplicated().sum())
print(claims_df.duplicated().sum())
print(payers_df.duplicated().sum())
print(providers_df.duplicated().sum())
print(revenue_df.duplicated().sum())
print(externalfact_df.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
#Data validation
claims_df = claims_df[claims_df['PatientID'].isin(patients_df['PatientID'])]
claims_df = claims_df[claims_df['PayerID'].isin(payers_df['PayerID'])]
claims_df = claims_df[claims_df['ProviderID'].isin(providers_df['ProviderID'])]
claims_df = claims_df[claims_df['ServiceDate']<claims_df['SubmissionDate']]
claims_df = claims_df[claims_df['SubmissionDate']<claims_df['ProcessedDate']]
claims_df = claims_df[claims_df['ClaimAmount']>=claims_df['Reimbursement']]

# %%
claims_df.shape
# Out:
# (50000, 10)

# %%
deniedreimbursement = claims_df['Reimbursement'].where(claims_df['DenialStatus'] == 'Yes')

# %%
deniedreimbursement.unique()
# Out:
# array([nan,  0.])

# %%
claims_yearly = claims_df.groupby(claims_df['ProcessedDate'].dt.year)['ClaimID'].count()
revenueclaims_yearly = revenue_df.groupby(revenue_df['MonthID'].dt.year)['ClaimsProcessed'].sum()

# %%
#Claims validation across claims and revenue tables
print("Claims table count:",claims_yearly)
print("Revenue table count:",revenueclaims_yearly)
# Out:
# Claims table count: ProcessedDate
# 2022    15725
# 2023    17216
# 2024    17059
# Name: ClaimID, dtype: int64
# Revenue table count: MonthID
# 2022    15725
# 2023    17216
# 2024    17059
# Name: ClaimsProcessed, dtype: int64

# %%
#Outlier Detection

fig,axes= plt.subplots(1,3,figsize = (10,4))

sns.boxplot(y='ClaimAmount',data=claims_df,ax=axes[0])
axes[0].set_title('ClaimAmount')
sns.boxplot(y='Reimbursement',data=claims_df,ax=axes[1])
axes[1].set_title('Reimbursement')
sns.boxplot(y='TotalRevenue',data=revenue_df,ax=axes[2])
axes[2].set_title('TotalRevenue')

plt.tight_layout()
plt.show()

# %%
#Feature Engineering

claims_df['SubmissionQuarter'] = claims_df['SubmissionDate'].dt.quarter
claims_df['SubmissionMonth'] = claims_df['SubmissionDate'].dt.month
claims_df['SubmissionWeekday'] = claims_df['SubmissionDate'].dt.weekday
claims_df['ProcessedQuarter'] = claims_df['ProcessedDate'].dt.quarter
claims_df['ProcessedMonth'] = claims_df['ProcessedDate'].dt.month
claims_df['ProcessedWeekday'] = claims_df['ProcessedDate'].dt.weekday

# %%
claims_df = claims_df.merge(payers_df[['PayerID','ReimbursementRate']],on='PayerID',how='left')

# %%
claims_df['ClaimValueProportion'] = (claims_df['Reimbursement']/claims_df['ClaimAmount']).round(2)
claims_df['SubmissionDelay'] = (claims_df['SubmissionDate'] - claims_df['ServiceDate']).dt.days
claims_df['ProcessingDelay'] = (claims_df['ProcessedDate'] - claims_df['SubmissionDate']).dt.days

# %%
claims_df['DelayRatio'] = (claims_df['SubmissionDelay']/claims_df['ProcessingDelay']).round(2)
claims_df['CTR_Ratio'] = ((claims_df['ClaimAmount']-claims_df['Reimbursement'])/claims_df['ClaimAmount']).round(2)

# %%
payer_denied_claims = claims_df[claims_df['DenialStatus'] == 'Yes'].groupby(claims_df['PayerID'])['ClaimID'].count()
payer_total_claims = claims_df.groupby(claims_df['PayerID'])['ClaimID'].count()
payer_denial_rate = (payer_denied_claims/payer_total_claims).round(2).reset_index(name='Payer_DenialRate')

# %%
claims_df = claims_df.merge(payer_denial_rate,on='PayerID',how='left')

# %%
avgreimbursed_rate_by_payer = claims_df.groupby(claims_df['PayerID'])['Reimbursement'].mean().round(2).reset_index()
avgreimbursed_rate_by_payer.rename(columns={'Reimbursement':'Payer_AvgReimbursementRate'},inplace=True)

# %%
claims_df = claims_df.merge(avgreimbursed_rate_by_payer,on='PayerID',how='left')

# %%
claims_df['Payer_DenialImpact'] = (claims_df['Payer_DenialRate']*(1-claims_df['ReimbursementRate'])).round(2)

# %%
avgclaim_by_patient = claims_df.groupby(claims_df['PatientID'])['ClaimAmount'].mean().round(2).reset_index()
avgclaim_by_patient.rename(columns={'ClaimAmount':'Patient_AvgClaimAmount'},inplace=True)

# %%
claims_df = claims_df.merge(avgclaim_by_patient,on='PatientID',how='left')

# %%
patient_denied_claims = claims_df[claims_df['DenialStatus'] == 'Yes'].groupby(claims_df['PatientID'])['ClaimID'].count()
patient_total_claims = claims_df.groupby(claims_df['PatientID'])['ClaimID'].count()
patient_denial_rate = (patient_denied_claims/patient_total_claims).round(2).reset_index(name='Patient_DenialRate')

# %%
claims_df = claims_df.merge(patient_denial_rate,on='PatientID',how='left')
claims_df['Patient_DenialRate'] = claims_df['Patient_DenialRate'].fillna(0.00)

# %%
provider_denied_claims = claims_df[claims_df['DenialStatus'] == 'Yes'].groupby(claims_df['ProviderID'])['ClaimID'].count()
provider_total_claims = claims_df.groupby(claims_df['ProviderID'])['ClaimID'].count()
provider_denial_rate = (provider_denied_claims/provider_total_claims).round(2).reset_index(name='Provider_DenialRate')
provider_total_claims = provider_total_claims.reset_index(name='Provider_TotalClaims')

# %%
claims_df = claims_df.merge(provider_denial_rate,on='ProviderID',how='left')
claims_df = claims_df.merge(provider_total_claims,on='ProviderID',how='left')

# %%
revenue_df['RevenuePerPatient'] = (revenue_df['TotalRevenue']/revenue_df['PatientsServed']).round(2)

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder

#Label Encoding
le = LabelEncoder()
patients_df['Gender'] = le.fit_transform(patients_df['Gender'])
claims_df['DenialStatus'] = le.fit_transform(claims_df['DenialStatus'])

#One-Hot Encoding
patients_df = pd.get_dummies(patients_df,columns=['InsuranceType'],dtype='int')
payers_df = pd.get_dummies(payers_df,columns=['PayerCategory'],dtype='int')
providers_df = pd.get_dummies(providers_df,columns=['Specialty'],dtype='int')

#Frequency Encoding
freq_publicencoding = externalfact_df['PublicEvents'].value_counts().to_dict()
freq_policyencoding = externalfact_df['PolicyChanges'].value_counts().to_dict()
externalfact_df['PublicEventsEncoded'] = externalfact_df['PublicEvents'].map(freq_publicencoding)
externalfact_df['PolicyChangesEncoded'] = externalfact_df['PolicyChanges'].map(freq_policyencoding)

# %%
# #Scaling

# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler

# #StandardScaling
# sscaler = StandardScaler()
# claims_df[['ClaimAmount','Reimbursement','ClaimValueProportion', 'SubmissionDelay', 'ProcessingDelay', 
#                   'DelayRatio', 'CTR_Ratio', 'Payer_DenialRate','ReimbursementRate', 'Payer_DenialImpact','Patient_DenialRate',
#                   'Provider_DenialRate']] = sscaler.fit_transform(claims_df[['ClaimAmount','Reimbursement','ClaimValueProportion', 
#                                                                              'SubmissionDelay', 'ProcessingDelay', 'DelayRatio', 'CTR_Ratio', 
#                                                                              'Payer_DenialRate','ReimbursementRate', 'Payer_DenialImpact',
#                                                                              'Patient_DenialRate','Provider_DenialRate']])
# patients_df[['Age']] = sscaler.fit_transform(patients_df[['Age']])
# revenue_df[['TotalRevenue','RevenuePerPatient']] = sscaler.fit_transform(revenue_df[['TotalRevenue','RevenuePerPatient']])
# externalfact_df[['InflationRate']] = sscaler.fit_transform(externalfact_df[['InflationRate']])

# #MinMaxScaler
# mscaler = MinMaxScaler()
# claims_df[['Payer_AvgReimbursementRate','Patient_AvgClaimAmount',
#            'Provider_TotalClaims']] = mscaler.fit_transform(claims_df[['Payer_AvgReimbursementRate','Patient_AvgClaimAmount','Provider_TotalClaims']])
# revenue_df[['ClaimsProcessed','PatientsServed']] = mscaler.fit_transform(revenue_df[['ClaimsProcessed','PatientsServed']])

# %%
scaled_patients_df = patients_df.copy()
scaled_claims_df = claims_df.copy()
scaled_externalfact_df = externalfact_df.copy()

# %%
#Scaling

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

#StandardScaling
sscaler = StandardScaler()
scaled_claims_df[['ClaimAmount','Reimbursement','ClaimValueProportion', 'SubmissionDelay', 'ProcessingDelay', 
                  'DelayRatio', 'CTR_Ratio', 'Payer_DenialRate','ReimbursementRate', 'Payer_DenialImpact','Patient_DenialRate',
                  'Provider_DenialRate','Payer_AvgReimbursementRate','Patient_AvgClaimAmount',
           'Provider_TotalClaims']] = sscaler.fit_transform(claims_df[['ClaimAmount','Reimbursement','ClaimValueProportion', 
                                                                             'SubmissionDelay', 'ProcessingDelay', 'DelayRatio', 'CTR_Ratio', 
                                                                             'Payer_DenialRate','ReimbursementRate', 'Payer_DenialImpact',
                                                                             'Patient_DenialRate','Provider_DenialRate','Payer_AvgReimbursementRate',
                                                                       'Patient_AvgClaimAmount',
           'Provider_TotalClaims']])
scaled_patients_df[['Age']] = sscaler.fit_transform(patients_df[['Age']])
#revenue_df[['TotalRevenue','RevenuePerPatient','ClaimsProcessed','PatientsServed']] = sscaler.fit_transform(revenue_df[['TotalRevenue',
                                                                                        #'RevenuePerPatient','ClaimsProcessed','PatientsServed']])
scaled_externalfact_df[['InflationRate']] = sscaler.fit_transform(externalfact_df[['InflationRate']])

# %%
new_claims_df = claims_df[['ClaimAmount',
       'Reimbursement', 'DenialStatus',  'ReimbursementRate', 'ClaimValueProportion',
       'SubmissionDelay', 'ProcessingDelay', 'DelayRatio', 'CTR_Ratio',
       'Payer_DenialRate', 'Payer_AvgReimbursementRate', 'Payer_DenialImpact',
       'Patient_AvgClaimAmount', 'Patient_DenialRate', 'Provider_DenialRate',
       'Provider_TotalClaims']].copy()

# %%
claims_corrmatrix = new_claims_df.corr()

# %%
claims_corrmatrix
# Out:
#                             ClaimAmount  Reimbursement  DenialStatus  \
# ClaimAmount                    1.000000       0.783582     -0.001854
# Reimbursement                  0.783582       1.000000     -0.461791
# DenialStatus                  -0.001854      -0.461791      1.000000
# ReimbursementRate              0.005439       0.001308      0.004198
# ClaimValueProportion           0.001705       0.541745     -0.853128
# SubmissionDelay                0.001326       0.002376     -0.002380
# ProcessingDelay               -0.002272      -0.001574     -0.000454
# DelayRatio                     0.002142       0.004211     -0.006391
# CTR_Ratio                     -0.001705      -0.541745      0.853128
# Payer_DenialRate               0.002817      -0.011263      0.024461
# Payer_AvgReimbursementRate     0.024725       0.029306     -0.012079
# Payer_DenialImpact            -0.005100      -0.001876     -0.002091
# Patient_AvgClaimAmount         0.445553       0.348991      0.003183
# Patient_DenialRate             0.003298      -0.200468      0.438595
# Provider_DenialRate            0.007747      -0.037694      0.098646
# Provider_TotalClaims          -0.004221      -0.005396      0.003236
#
#                             ReimbursementRate  ClaimValueProportion  \
# ClaimAmount                          0.005439              0.001705
# Reimbursement                        0.001308              0.541745
# DenialStatus                         0.004198             -0.853128
# ReimbursementRate                    1.000000             -0.004641
# ClaimValueProportion                -0.004641              1.000000
# SubmissionDelay                     -0.000274              0.003041
# ProcessingDelay                      0.004127              0.001308
# DelayRatio                           0.002506              0.005336
# CTR_Ratio                            0.004641             -1.000000
# Payer_DenialRate                     0.188125             -0.027838
# Payer_AvgReimbursementRate           0.044641              0.018502
# Payer_DenialImpact                  -0.972469              0.002193
# Patient_AvgClaimAmount               0.003168             -0.000019
# Patient_DenialRate                   0.005914             -0.376627
# Provider_DenialRate                  0.007650             -0.082314
# Provider_TotalClaims                 0.006143             -0.002141
#
#                             SubmissionDelay  ProcessingDelay  DelayRatio  \
# ClaimAmount                        0.001326        -0.002272    0.002142
# Reimbursement                      0.002376        -0.001574    0.004211
# DenialStatus                      -0.002380        -0.000454   -0.006391
# ReimbursementRate                 -0.000274         0.004127    0.002506
# ClaimValueProportion               0.003041         0.001308    0.005336
# SubmissionDelay                    1.000000        -0.006262    0.323678
# ProcessingDelay                   -0.006262         1.000000   -0.541875
# DelayRatio                         0.323678        -0.541875    1.000000
# CTR_Ratio                         -0.003041        -0.001308   -0.005336
# Payer_DenialRate                  -0.001966        -0.000678    0.001884
# Payer_AvgReimbursementRate        -0.002852         0.006157   -0.006487
# Payer_DenialImpact                 0.000437        -0.003788   -0.003147
# Patient_AvgClaimAmount            -0.001389         0.004296   -0.004641
# Patient_DenialRate                 0.001134         0.004574   -0.007606
# Provider_DenialRate                0.007369         0.005214   -0.003489
# Provider_TotalClaims              -0.001438        -0.001903    0.003259
#
#                             CTR_Ratio  Payer_DenialRate  \
# ClaimAmount                 -0.001705          0.002817
# Reimbursement               -0.541745         -0.011263
# DenialStatus                 0.853128          0.024461
# ReimbursementRate            0.004641          0.188125
# ClaimValueProportion        -1.000000         -0.027838
# SubmissionDelay             -0.003041         -0.001966
# ProcessingDelay             -0.001308         -0.000678
# DelayRatio                  -0.005336          0.001884
# CTR_Ratio                    1.000000          0.027838
# Payer_DenialRate             0.027838          1.000000
# Payer_AvgReimbursementRate  -0.018502         -0.384344
# Payer_DenialImpact          -0.002193         -0.092043
# Patient_AvgClaimAmount       0.000019         -0.003292
# Patient_DenialRate           0.376627          0.011202
# Provider_DenialRate          0.082314          0.006454
# Provider_TotalClaims         0.002141         -0.005339
#
#                             Payer_AvgReimbursementRate  Payer_DenialImpact  \
# ClaimAmount                                   0.024725           -0.005100
# Reimbursement                                 0.029306           -0.001876
# DenialStatus                                 -0.012079           -0.002091
# ReimbursementRate                             0.044641           -0.972469
# ClaimValueProportion                          0.018502            0.002193
# SubmissionDelay                              -0.002852            0.000437
# ProcessingDelay                               0.006157           -0.003788
# DelayRatio                                   -0.006487           -0.003147
# CTR_Ratio                                    -0.018502           -0.002193
# Payer_DenialRate                             -0.384344           -0.092043
# Payer_AvgReimbursementRate                    1.000000           -0.064022
# Payer_DenialImpact                           -0.064022            1.000000
# Patient_AvgClaimAmount                        0.008704           -0.002853
# Patient_DenialRate                           -0.003059           -0.005791
# Provider_DenialRate                          -0.007348           -0.006585
# Provider_TotalClaims                         -0.001226           -0.006645
#
#                             Patient_AvgClaimAmount  Patient_DenialRate  \
# ClaimAmount                               0.445553            0.003298
# Reimbursement                             0.348991           -0.200468
# DenialStatus                              0.003183            0.438595
# ReimbursementRate                         0.003168            0.005914
# ClaimValueProportion                     -0.000019           -0.376627
# SubmissionDelay                          -0.001389            0.001134
# ProcessingDelay                           0.004296            0.004574
# DelayRatio                               -0.004641           -0.007606
# CTR_Ratio                                 0.000019            0.376627
# Payer_DenialRate                         -0.003292            0.011202
# Payer_AvgReimbursementRate                0.008704           -0.003059
# Payer_DenialImpact                       -0.002853           -0.005791
# Patient_AvgClaimAmount                    1.000000            0.007401
# Patient_DenialRate                        0.007401            1.000000
# Provider_DenialRate                       0.011519            0.046051
# Provider_TotalClaims                     -0.003198            0.002268
#
#                             Provider_DenialRate  Provider_TotalClaims
# ClaimAmount                            0.007747             -0.004221
# Reimbursement                         -0.037694             -0.005396
# DenialStatus                           0.098646              0.003236
# ReimbursementRate                      0.007650              0.006143
# ClaimValueProportion                  -0.082314             -0.002141
# SubmissionDelay                        0.007369             -0.001438
# ProcessingDelay                        0.005214             -0.001903
# DelayRatio                            -0.003489              0.003259
# CTR_Ratio                              0.082314              0.002141
# Payer_DenialRate                       0.006454             -0.005339
# Payer_AvgReimbursementRate            -0.007348             -0.001226
# Payer_DenialImpact                    -0.006585             -0.006645
# Patient_AvgClaimAmount                 0.011519             -0.003198
# Patient_DenialRate                     0.046051              0.002268
# Provider_DenialRate                    1.000000              0.039194
# Provider_TotalClaims                   0.039194              1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(claims_corrmatrix,annot=True,cmap='crest',fmt=".2f")
plt.show()

# %%
new_claims_df = new_claims_df.drop(columns=['CTR_Ratio','ClaimValueProportion','Payer_DenialImpact'])

# %%
#Handling missing values
print(patients_df.isnull().sum())
print(claims_df.isnull().sum())
print(payers_df.isnull().sum())
print(providers_df.isnull().sum())
print(revenue_df.isnull().sum())
print(externalfact_df.isnull().sum())
# Out:
# PatientID                   0
# Age                         0
# Gender                      0
# City                        0
# State                       0
# InsuranceType_Government    0
# InsuranceType_Private       0
# dtype: int64
# ClaimID                       0
# PatientID                     0
# PayerID                       0
# ProviderID                    0
# ClaimAmount                   0
# Reimbursement                 0
# DenialStatus                  0
# ServiceDate                   0
# SubmissionDate                0
# ProcessedDate                 0
# SubmissionQuarter             0
# SubmissionMonth               0
# SubmissionWeekday             0
# ProcessedQuarter              0
# ProcessedMonth                0
# ProcessedWeekday              0
# ReimbursementRate             0
# ClaimValueProportion          0
# SubmissionDelay               0
# ProcessingDelay               0
# DelayRatio                    0
# CTR_Ratio                     0
# Payer_DenialRate              0
# Payer_AvgReimbursementRate    0
# Payer_DenialImpact            0
# Patient_AvgClaimAmount        0
# Patient_DenialRate            0
# Provider_DenialRate           0
# Provider_TotalClaims          0
# dtype: int64
# PayerID                     0
# PayerName                   0
# ReimbursementRate           0
# PayerCategory_Government    0
# PayerCategory_Private       0
# dtype: int64
# ProviderID                    0
# ProviderName                  0
# City                          0
# State                         0
# Specialty_Cardiology          0
# Specialty_General Medicine    0
# Specialty_Neurology           0
# Specialty_Orthopedics         0
# Specialty_Pediatrics          0
# dtype: int64
# MonthID              0
# TotalRevenue         0
# ClaimsProcessed      0
# PatientsServed       0
# RevenuePerPatient    0
# dtype: int64
# MonthID                 0
# InflationRate           0
# PublicEvents            0
# PolicyChanges           0
# PublicEventsEncoded     0
# PolicyChangesEncoded    0
# dtype: int64

# %%
#Duplicate values
print(patients_df.duplicated().sum())
print(claims_df.duplicated().sum())
print(payers_df.duplicated().sum())
print(providers_df.duplicated().sum())
print(revenue_df.duplicated().sum())
print(externalfact_df.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
new_claims_df.columns

# %%
plt.figure(figsize=(12,8))

columns = ['ClaimAmount', 'Reimbursement', 'ReimbursementRate','DelayRatio',
       'SubmissionDelay', 'ProcessingDelay', 'Payer_DenialRate',
       'Payer_AvgReimbursementRate', 'Patient_AvgClaimAmount',
       'Patient_DenialRate', 'Provider_DenialRate', 'Provider_TotalClaims']

for i,col in enumerate(columns,1):
    plt.subplot(1,len(columns),i)
    sns.boxplot(y=claims_df[col])
    #plt.title(col)
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=claims_df,x='DelayRatio')
# Out:
# <Axes: xlabel='DelayRatio', ylabel='Count'>

# %%
patients_df['Gender'].value_counts()
# Out:
# Gender
# 1    5076
# 0    4924
# Name: count, dtype: int64

# %%
sns.scatterplot(x='ClaimAmount', y='Reimbursement', data=claims_df,hue='DenialStatus')
# Out:
# <Axes: xlabel='ClaimAmount', ylabel='Reimbursement'>

# %%
sns.lineplot(x='SubmissionMonth',y='Payer_DenialRate',marker='o',color='blue',label='Payer',data=claims_df)
sns.lineplot(x='SubmissionMonth',y='Patient_DenialRate',marker='s',color='red',label='Patient',data=claims_df)
sns.lineplot(x='SubmissionMonth',y='Provider_DenialRate',marker='D',color='green',label='Provider',data=claims_df)
plt.xlabel("Months")
plt.ylabel("Denial Rate")
# Out:
# Text(0, 0.5, 'Denial Rate')
